# %%
def SaySomething():
    print('Hello world')

# %%
SaySomething()
# Out:
# Hello world

# %%
def Fommating(name):
    print(f"Hello {name}") #Áp dụng vào formmmating

# %%
Fommating('Dũng')
# Out:
# Hello Dũng
