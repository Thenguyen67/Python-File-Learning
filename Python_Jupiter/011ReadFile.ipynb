# %%
a = open('../FileRead/Text1.txt', 'r', encoding= 'utf-8') 
# r Chỉ đọc
# w Cho phép ghi đè, không cho đọc
# a Chèn thêm vào cuối, không thể chỉnh sửa thông tin trước 

b = a.readlines()

print(a.readable())
print(b)

for i in b:
    i = i.replace('\n', ' ')
    print(i)


a.close()
# Out:
# True
# ['Thế - 001\n', 'Dũng - 002\n', 'Nam - 003\n', 'Mai - 004\n', 'Huy - 005\n', 'Hùng - 006']
# Thế - 001
# Dũng - 002
# Nam - 003
# Mai - 004
# Huy - 005
# Hùng - 006
