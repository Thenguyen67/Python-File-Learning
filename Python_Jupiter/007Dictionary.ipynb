# %%
TuDienBachKhoa = {
    'hello' : 'xin chào', # Có thể đánh dấu 0, 1, 2, 3 
    'goodbye' : 'tạm biệt',
    'good night' : 'chúc ngủ '
}

# %%
print(TuDienBachKhoa['hello'])
print(TuDienBachKhoa.get('goodbye'))
# Out:
# xin chào
# tạm biệt

# %%
print(TuDienBachKhoa.get('good afternoon', 'In đoạn này ra nếu từ không tồn tại'))
# Out:
# In đoạn này ra nếu từ không tồn tại
