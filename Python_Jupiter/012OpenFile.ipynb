# %%
a = open('../FileRead/Text1.txt', 'a', encoding= 'utf-8') #Thêm mới một dòng vào 
a.write('\nHiền - 007')
a.write('\nDung - 008')

a.close()

# %%
b = open('../FileRead/Text2.txt', 'w', encoding= 'utf-8') #Ghi đè lên dữ liệu hoặc tạo file mới
b.write('\nHiền - 007')
b.write('\nDung - 008')
# Out:
# 11
