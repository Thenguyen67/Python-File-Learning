# %%
a = ['A', 'B', 'C', 'D', 'E', 'R']
print(a)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'R']

# %%
print(a[1:3])
# Out:
# ['B', 'C']

# %%
a.append('Y')
print(a)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'R', 'Y']

# %%
a.insert(1, 'T')
print(a)
# Out:
# ['A', 'T', 'B', 'C', 'D', 'E', 'R', 'Y']

# %%
a.pop()
print(a)
# Out:
# ['A', 'T', 'B', 'C', 'D', 'E', 'R']

# %%
b = [1, 1, 1, 2, 3, 5, 5]
c = b.count(1)
print(c)
# Out:
# 3

# %%
d = [4, 5, 2, 1, 10, 7]
d.sort()
print(d)
# Out:
# [1, 2, 4, 5, 7, 10]

# %%
a.reverse()
print(a)
# Out:
# ['R', 'E', 'D', 'C', 'B', 'T', 'A']

# %%
Arr_Origin = [0, 1, 2, 3]
Arr_Copy = Arr_Origin.copy()

print(Arr_Copy)
# Out:
# [0, 1, 2, 3]
