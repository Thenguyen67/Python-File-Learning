# %%
import math

# %%
n = 2
a = -1
b = 2.3
c = 2.7

# %%
print(str(n) + " là một chuỗi trong trường hợp này") #Chỉ có thể cộng chuỗi với chuỗi
# Out:
# 2 là một chuỗi trong trường hợp này

# %%
print(abs(a))
print(pow(n, 2))
# Out:
# 1
# 4

# %%
print(round(b))
print(round(c))
# Out:
# 2
# 3

# %%
print(math.floor(b))
print(math.floor(c))
# Out:
# 2
# 2

# %%
n = 2
text = "{} là số năm tôi đã học trên đại học"

print(text.format(n))
# Out:
# 2 là số năm tôi đã học trên đại học

# %%
fd = 2
hd = 3

text = "Tôi {} tuổi còn Nam {} tuổi"
print(text.format(fd, hd))
# Out:
# Tôi 2 tuổi còn Nam 3 tuổi

# %%
fd = 2
hd = 3

text = "Tôi {1} tuổi còn Nam {0} tuổi"
print(text.format(fd, hd))
# Out:
# Tôi 3 tuổi còn Nam 2 tuổi
