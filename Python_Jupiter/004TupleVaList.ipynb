# %%
a = (100, 200) #tuple
print(a[0])
print(a[1])
#Không thể gán hay thay đổi giá trị trong tuple
#Không thể thêm, xóa phần tử
# Out:
# 100
# 200

# %%
b =[(1, 2), (3, 4), (5, 6)] #List chứa các tuple
print(b[0])
# Out:
# (1, 2)
